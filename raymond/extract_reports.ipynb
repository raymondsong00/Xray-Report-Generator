# %%
import re
import pandas as pd
import numpy as np
from glob import glob

# %%
pd.read_csv('/home/llm-hackathon/Downloads/fixed-data-csv/all-reports-available-xrays-after2020-final.csv')
# Out:
#        Unnamed: 0  AccessionId                    DocumentTitle DocumentDate  \
# 0               0     53333541          X-RAY CHEST SINGLE VIEW    1/23/2021
# 1               1     53993975  X-RAY CHEST FRONTAL AND LATERAL     9/2/2021
# 2               2     53513416          X-RAY CHEST SINGLE VIEW    3/28/2021
# 3               3     53662146          X-RAY CHEST SINGLE VIEW    5/17/2021
# 4               4     53456291  X-RAY CHEST FRONTAL AND LATERAL     3/8/2021
# ...           ...          ...                              ...          ...
# 66490       66630     54167443  X-RAY CHEST FRONTAL AND LATERAL    10/7/2021
# 66491       66631     53726745          X-RAY CHEST SINGLE VIEW     6/7/2021
# 66492       66632     53727052  X-RAY CHEST FRONTAL AND LATERAL     6/7/2021
# 66493       66633     53530452          X-RAY CHEST SINGLE VIEW     4/2/2021
# 66494       66634     53277988  X-RAY CHEST FRONTAL AND LATERAL     1/7/2021
#
# ...

# %%
rep_a2020 = pd.read_csv('/data/UCSD_cxr/all-reports-available-xrays-after2020.csv').dropna()

# %%
rep_a2020['ReportText'][0]
# Out:
# 'EXAM DESCRIPTION:  X-RAY CHEST SINGLE VIEW    CLINICAL HISTORY:  Dyspnea    COMPARISON:  Chest radiograph 2/19/2020    FINDINGS:  Lines and Tubes: None  Mediastinum: The cardiomediastinal silhouette is unremarkable. No lymphadenopathy is appreciated.  Lungs: Lungs are well expanded. Streaky bibasal opacities, left greater than right.  Pleura: No left pleural effusion. The right costophrenic sulcus is not imaged. No pneumothorax.  Bones and soft tissues: Partially visualized ORIF hardware of the right humerus without acute hardware complication. Multiple lateral right rib healed fracture deformities.    CONCURRENT SUPERVISION:  I have reviewed the images and agree with the resident interpretation.           Preliminary created by: Besser, Alexandra   Signed by: Jacobs, Kathleen 01/23/2021 10:24:31  IMPRESSION:  IMPRESSION:  Streaky bibasal opacities which may be on the basis of atelectasis. No definite focal consolidation.    '
