# %%
from eval_script import *

# %%
data_dir = './03-03-24-01/data'
test_inference_path = os.path.join(data_dir, 'test_inference.csv')

test_inference = pd.read_csv(test_inference_path)

# %%
test_inference
# Out:
#             id phonetic_id             author  \
# 0     54059849      Abifel  Jacobs, Kathleen
# 1     53428634      Aburik       Hahn, Lewis
# 2     53439132    Achoroos  Smitaman, Edward
# 3     50219723   Ackoofdek      Wyatt, Alvin
# 4     52165792     Adefoup  Weihe, Elizabeth
# ...        ...         ...                ...
# 2083  53657129      Yuhiko   Kligerman, Seth
# 2084  53670978     Yutexug  Meisinger, Quinn
# 2085  52495793      Zedusi    Brouha, Sharon
# 2086  53245718     Zideeru       Yen, Andrew
# 2087  54233739      Zomome       Yen, Andrew
#
#                                          llava_findings  \
# 0     FINDINGS:\nLines and Tubes: None\nMediastinum:...
# 1     FINDINGS:\nLines and Tubes: None  Mediastinum:...
# 2     FINDINGS:\nLines and Tubes: None  Mediastinum:...
# 3     FINDINGS:\nLines and Tubes: None  Mediastinum:...
# 4     FINDINGS:\nLines and Tubes: None  Mediastinum:...
# ...                                                 ...
# ...

# %%
test_inference[test_inference['llava_rep_summary'].str.contains('_ZNK3c106SymIntltEl')]
# Out:
# Empty DataFrame
# Columns: [id, phonetic_id, author, llava_findings, llava_impression, llava_report, radiologist_report, radiologist_findings, radiologist_impression, similarity, impression_similarity, findings_similarity, is_si_l, is_si_r, lf_len, li_len, rf_len, ri_len, llava_rep_summary, radiologist_rep_summary]
# Index: []
