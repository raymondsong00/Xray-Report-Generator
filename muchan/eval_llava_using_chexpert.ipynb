# %%
import pandas as pd

# %%
sample_predictions = [
    {"question_id": 0, "prompt": "AUTHOR: Tran, Vu , CLINICAL HISTORY: None. \nBased on AUTHOR and CLINICAL HISTORY information, suppose you were the named specialist AUTHOR, provide me a detailed report reading this chest X-ray as closely resembling the style of this AUTHOR as possible.", "text": "FINDINGS: Lines and Tubes: None  Mediastinum: The cardiomediastinal silhouette is unchanged. No lymphadenopathy is appreciated.  Lungs: The lungs are clear.  Pleura: No pneumothorax or effusion.  Bones and soft tissues: UnchangedIMPRESSION: No acute cardiopulmonary findings.", "answer_id": "hW4ihynaT7CJrh6HV7gDyn", "model_id": "llava-v1.5-13b-02-11-24-task-lora", "metadata": {}},
    {"question_id": 1, "prompt": "AUTHOR: Kligerman, Seth , CLINICAL HISTORY: None. \nBased on AUTHOR and CLINICAL HISTORY information, suppose you were the named specialist AUTHOR, provide me a detailed report reading this chest X-ray as closely resembling the style of this AUTHOR as possible.", "text": "FINDINGS: Lines and Tubes: None  Mediastinum: The cardiomediastinal silhouette is unchanged. No lymphadenopathy is appreciated.  Lungs: The lungs are clear.  Pleura: No pneumothorax or effusion.  Bones and soft tissues: UnchangedIMPRESSION: No explanation for chest pain on radiograph", "answer_id": "hXicPyKtG8kCjDHMQzj5Uv", "model_id": "llava-v1.5-13b-02-11-24-task-lora", "metadata": {}},
    {"question_id": 2, "prompt": "AUTHOR: Meisinger, Quinn , CLINICAL HISTORY: None. \nBased on AUTHOR and CLINICAL HISTORY information, suppose you were the named specialist AUTHOR, provide me a detailed report reading this chest X-ray as closely resembling the style of this AUTHOR as possible.", "text": "FINDINGS: See impression.\n\n\n\n\n*\n\nSigned by: Meisinger, Quinn 01/22/2020 21:08:38IMPRESSION: *1.\nNo acute cardiopulmonary disease.\n\n*2.\nStable cardiac silhouette.\n\n*3.\nNo pneumothorax or pleural effusion.\n\n*4.\nNo acute osseous abnormalities.", "answer_id": "kRDZw5qNfDsV6aLNgccBbq", "model_id": "llava-v1.5-13b-02-11-24-task-lora", "metadata": {}},
    {"question_id": 3, "prompt": "AUTHOR: Elchico, Melanie , CLINICAL HISTORY: None. \nBased on AUTHOR and CLINICAL HISTORY information, suppose you were the named specialist AUTHOR, provide me a detailed report reading this chest X-ray as closely resembling the style of this AUTHOR as possible.", "text": "FINDINGS: Lines and Tubes: None  Mediastinum: The cardiomediastinal silhouette is unchanged.  Lungs: The lungs are clear.  Pleura: No pneumothorax or effusion.  Bones and soft tissues: UnchangedIMPRESSION: No acute cardiopulmonary process.", "answer_id": "9PBZaWxwwUcuSKH3GxHw8P", "model_id": "llava-v1.5-13b-02-11-24-task-lora", "metadata": {}},
    {"question_id": 4, "prompt": "AUTHOR: Yen, Andrew , CLINICAL HISTORY: None. \nBased on AUTHOR and CLINICAL HISTORY information, suppose you were the named specialist AUTHOR, provide me a detailed report reading this chest X-ray as closely resembling the style of this AUTHOR as possible.", "text": "FINDINGS: See impression.IMPRESSION: No pleural effusion or pneumothorax demonstrated.    No consolidation.    Unchanged cardiomediastinal silhouette.    No acute osseous abnormality identified.", "answer_id": "fWkFQBUuvsoLwAq6iVKoix", "model_id": "llava-v1.5-13b-02-11-24-task-lora", "metadata": {}}
]
with open('./eval_report.csv', 'w') as f:
    for sample in sample_predictions:
        content = sample['text']
        f.write(f'"{content}"\n')

# %%
labeled_sample_pred_df = pd.read_csv('eval_report_labeled.csv')
group_truth = pd.read_csv('/data/CheXpert-v1.0/chexpert_used_for_testing_llava.csv')
labeled_sample_pred_df.iloc[:,1:]
# Out:
#    No Finding  Enlarged Cardiomediastinum  Cardiomegaly  Lung Lesion  \
# 0         NaN                         1.0           NaN          NaN
# 1         NaN                         1.0           NaN          NaN
# 2         NaN                         NaN          -1.0          NaN
# 3         NaN                         1.0           NaN          NaN
# 4         NaN                        -1.0           NaN          NaN
#
#    Lung Opacity  Edema  Consolidation  Pneumonia  Atelectasis  Pneumothorax  \
# 0           NaN    NaN            NaN        NaN          NaN           0.0
# 1           NaN    NaN            NaN        NaN          NaN           0.0
# 2           NaN    NaN            NaN        NaN          NaN           0.0
# 3           NaN    NaN            NaN        NaN          NaN           0.0
# 4           NaN    NaN            0.0        NaN          NaN           0.0
#
#    Pleural Effusion  Pleural Other  Fracture  Support Devices
# ...

# %%
corresponding_ground_truth = group_truth.iloc[:,5:].head()
corresponding_ground_truth = corresponding_ground_truth[list(labeled_sample_pred_df.columns)[1:]]
corresponding_ground_truth
# Out:
#    No Finding  Enlarged Cardiomediastinum  Cardiomegaly  Lung Lesion  \
# 0         1.0                         NaN           NaN          NaN
# 1         NaN                         NaN           1.0          NaN
# 2         NaN                         NaN           NaN          NaN
# 3         NaN                         NaN           NaN          NaN
# 4         NaN                         NaN           NaN          NaN
#
#    Lung Opacity  Edema  Consolidation  Pneumonia  Atelectasis  Pneumothorax  \
# 0           NaN    NaN            NaN        NaN          NaN           0.0
# 1           1.0   -1.0           -1.0        NaN         -1.0           NaN
# 2           1.0    NaN           -1.0        NaN          NaN           NaN
# 3           1.0    NaN           -1.0        NaN          NaN           NaN
# 4           NaN    1.0            NaN        NaN          NaN           0.0
#
#    Pleural Effusion  Pleural Other  Fracture  Support Devices
# ...
